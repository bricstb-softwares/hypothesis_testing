# %%
# !pip install dorothy-sdk
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 18.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 6.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for dorothy-sdk: filename=dorothy_sdk-1.4.8-py3-none-any.whl size=24420 sha256=c4f26d619caac1a43905d5f9061a11b70e55bcd70cbf23b1863ccb8d1b51bbe2
#   Stored in directory: /home/otto.tavares/.cache/pip/wheels/19/d3/52/b5fc877fc4d8a72de45f4fde9e5622117fa7841df0050801c3
# Successfully built dorothy-sdk
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.7
#     Uninstalling psutil-5.9.7:
# ...

# %%
from dorothy_sdk import Client
import requests
import json
import pandas as pd
import pickle
import cv2
from PIL import Image
import PIL
save_imgs = False
headers = {
      "Authorization": "Token b16fe0fc92088c4840a98160f3848839e68b1148",
}

response_report = requests.get('https://dorothy-image.lps.ufrj.br/report/', headers=headers)

if response_report.status_code == 502:
    print('Dorothy reports are out of service - Working with dorothy metadata')
    data_report = pd.read_csv('/home/brics/public/brics_data/SantaCasa/imageamento_anonimizado_valid/raw/SantaCasa_imageamento_anonimizado_valid_table_from_raw.csv')
else:
    data_report = json.loads(response_report.content)
# Out:
# Dorothy reports are out of service - Working with dorothy metadata

# %%
for im in data_report['metadata']:
    print(im)
# Out:
# {'gender': 'female', 'age': 49, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# {'gender': 'male', 'age': 62, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# {'gender': 'male', 'age': 45, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# {'gender': 'female', 'age': 63, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# {'gender': 'female', 'age': 32, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# {'gender': 'female', 'age': 23, 'has_tb': False, 'original_report': None, 'date_exam': None, 'synthetic': False, 'additional_information': None}
# ...
